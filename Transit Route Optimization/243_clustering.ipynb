# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('rideshare_kaggle.csv')
x = df[["latitude","longitude"]]

# %%
from sklearn.cluster import KMeans
wcss = []
for k in range(1,13):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,13),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,13,1))
plt.ylabel("WCSS")
plt.show()

# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in c:\users\16695\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: numpy in c:\users\16695\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\16695\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\16695\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\16695\anaconda3\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\16695\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\16695\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\16695\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
x_5 = x.copy()
km_5 = KMeans(n_clusters=5)
clusters = km_5.fit_predict(x_5)
x_5["label"] = clusters
centroids = km_5.cluster_centers_
y = np.delete(centroids,[2],axis=1)
import folium
centroid = y.tolist()
# Plotting the centroids on google map using Folium library.
map = folium.Map(location=[42.3372844, -71.0657244], zoom_start = 25)
for point in range(0, len(centroid)):
    folium.Marker(centroid[point], popup = centroid[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84b920e44b68e9c39a9631b503d48605 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84b920e44b68e9c39a9631b503d48605&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84b920e44b68e9c39a9631b503d48605 = L.map(
#                 &quot;map_84b920e44b68e9c39a9631b503d48605&quot;,
#                 {
#                     center: [42.3372844, -71.0657244],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4a9106787046a7911d5a92b024909c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_84b920e44b68e9c39a9631b503d48605);
#
#
#             var marker_da18ef832fd02c15abd65837c1ac81c1 = L.marker(
#                 [42.246234392276904, -71.04713290276769],
#                 {}
#             ).addTo(map_84b920e44b68e9c39a9631b503d48605);
#
#
#         var popup_220c99a667e452f8a30acad932bc34c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f690959f8de06df4a3899aee572c99e = $(`&lt;div id=&quot;html_2f690959f8de06df4a3899aee572c99e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.246234392276904, -71.04713290276769]&lt;/div&gt;`)[0];
#                 popup_220c99a667e452f8a30acad932bc34c8.setContent(html_2f690959f8de06df4a3899aee572c99e);
#
#
#
#         marker_da18ef832fd02c15abd65837c1ac81c1.bindPopup(popup_220c99a667e452f8a30acad932bc34c8)
#         ;
#
#
#
#
#             var marker_393cb196c3491514d546895503b92d54 = L.marker(
#                 [42.361152892161655, -71.06080823237899],
#                 {}
#             ).addTo(map_84b920e44b68e9c39a9631b503d48605);
#
#
#         var popup_64119b411782264ff28444cc70a43c8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_889dc299386cadcdc99d14caa982e827 = $(`&lt;div id=&quot;html_889dc299386cadcdc99d14caa982e827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.361152892161655, -71.06080823237899]&lt;/div&gt;`)[0];
#                 popup_64119b411782264ff28444cc70a43c8f.setContent(html_889dc299386cadcdc99d14caa982e827);
#
#
#
#         marker_393cb196c3491514d546895503b92d54.bindPopup(popup_64119b411782264ff28444cc70a43c8f)
#         ;
#
#
#
#
#             var marker_2df7e78de7260853bb63039ef51c3c98 = L.marker(
#                 [42.35039439053213, -71.09251564492061],
#                 {}
#             ).addTo(map_84b920e44b68e9c39a9631b503d48605);
#
#
#         var popup_283b2f8fd1c1bef68560675bf1638ab2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_030cad3f41b49971b834c49bda00daa3 = $(`&lt;div id=&quot;html_030cad3f41b49971b834c49bda00daa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.35039439053213, -71.09251564492061]&lt;/div&gt;`)[0];
#                 popup_283b2f8fd1c1bef68560675bf1638ab2.setContent(html_030cad3f41b49971b834c49bda00daa3);
#
#
#
#         marker_2df7e78de7260853bb63039ef51c3c98.bindPopup(popup_283b2f8fd1c1bef68560675bf1638ab2)
#         ;
#
#
#
#
#             var marker_7ef957627cf0ee5b5d6e91c6b8005c4d = L.marker(
#                 [42.35816841627161, -71.06801220228802],
#                 {}
#             ).addTo(map_84b920e44b68e9c39a9631b503d48605);
#
#
#         var popup_bc457576d6aa6a2f453f823902c8a6aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c87166f9bdd4a7e81dc9aceb0937a40 = $(`&lt;div id=&quot;html_0c87166f9bdd4a7e81dc9aceb0937a40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.35816841627161, -71.06801220228802]&lt;/div&gt;`)[0];
#                 popup_bc457576d6aa6a2f453f823902c8a6aa.setContent(html_0c87166f9bdd4a7e81dc9aceb0937a40);
#
#
#
#         marker_7ef957627cf0ee5b5d6e91c6b8005c4d.bindPopup(popup_bc457576d6aa6a2f453f823902c8a6aa)
#         ;
#
#
#
#
#             var marker_ad68979345531ba2c923a0f882197a44 = L.marker(
#                 [42.35471028681022, -71.06690664283846],
#                 {}
#             ).addTo(map_84b920e44b68e9c39a9631b503d48605);
#
#
#         var popup_b9eca803e35b5ebe9915a7cac0ddc27d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58a04771c89155ed30b3b24d6252ebef = $(`&lt;div id=&quot;html_58a04771c89155ed30b3b24d6252ebef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.35471028681022, -71.06690664283846]&lt;/div&gt;`)[0];
#                 popup_b9eca803e35b5ebe9915a7cac0ddc27d.setContent(html_58a04771c89155ed30b3b24d6252ebef);
#
#
#
#         marker_ad68979345531ba

# %%
sns.factorplot(data = x_5, x = 'label',kind = 'count')
# Out:
# C:\Users\16695\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
x_10 = x.copy()
km_10 = KMeans(n_clusters=10)
clusters = km_10.fit_predict(x_10)
x_10["label"] = clusters
centroids = km_10.cluster_centers_
y = np.delete(centroids,[2],axis=1)
import folium
centroid = y.tolist()
# Plotting the centroids on google map using Folium library.
map = folium.Map(location=[42.3372844, -71.0657244], zoom_start = 25)
for point in range(0, len(centroid)):
    folium.Marker(centroid[point], popup = centroid[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3ccab4d49b5201c804b8879c7984fe8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3ccab4d49b5201c804b8879c7984fe8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3ccab4d49b5201c804b8879c7984fe8 = L.map(
#                 &quot;map_d3ccab4d49b5201c804b8879c7984fe8&quot;,
#                 {
#                     center: [42.3372844, -71.0657244],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e80a10c0a787a76c8a942a0c13ce8132 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d3ccab4d49b5201c804b8879c7984fe8);
#
#
#             var marker_1d58c0935bd758287502ec80b80cb314 = L.marker(
#                 [42.3588, -71.0707],
#                 {}
#             ).addTo(map_d3ccab4d49b5201c804b8879c7984fe8);
#
#
#         var popup_6aff9a9fec55e57ed4c6d90f8f49ebc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_00983d68f818e4e7b132355dcc0c18cf = $(`&lt;div id=&quot;html_00983d68f818e4e7b132355dcc0c18cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.3588, -71.0707]&lt;/div&gt;`)[0];
#                 popup_6aff9a9fec55e57ed4c6d90f8f49ebc0.setContent(html_00983d68f818e4e7b132355dcc0c18cf);
#
#
#
#         marker_1d58c0935bd758287502ec80b80cb314.bindPopup(popup_6aff9a9fec55e57ed4c6d90f8f49ebc0)
#         ;
#
#
#
#
#             var marker_70bd7c3705d17dbf6e92f04804831ce8 = L.marker(
#                 [42.3647, -71.0542],
#                 {}
#             ).addTo(map_d3ccab4d49b5201c804b8879c7984fe8);
#
#
#         var popup_e49d83f14b48938150bfdc26ee582188 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_689f3a16a59295d8d1771c2dff1c5427 = $(`&lt;div id=&quot;html_689f3a16a59295d8d1771c2dff1c5427&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.3647, -71.0542]&lt;/div&gt;`)[0];
#                 popup_e49d83f14b48938150bfdc26ee582188.setContent(html_689f3a16a59295d8d1771c2dff1c5427);
#
#
#
#         marker_70bd7c3705d17dbf6e92f04804831ce8.bindPopup(popup_e49d83f14b48938150bfdc26ee582188)
#         ;
#
#
#
#
#             var marker_a5f388af0432a984a8236716ca761d56 = L.marker(
#                 [42.36557547855409, -71.06402562608102],
#                 {}
#             ).addTo(map_d3ccab4d49b5201c804b8879c7984fe8);
#
#
#         var popup_78af9ac5c87ba4ccd1d7005b1088205e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b93d1af569588a4f58c7c965375dd27b = $(`&lt;div id=&quot;html_b93d1af569588a4f58c7c965375dd27b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.36557547855409, -71.06402562608102]&lt;/div&gt;`)[0];
#                 popup_78af9ac5c87ba4ccd1d7005b1088205e.setContent(html_b93d1af569588a4f58c7c965375dd27b);
#
#
#
#         marker_a5f388af0432a984a8236716ca761d56.bindPopup(popup_78af9ac5c87ba4ccd1d7005b1088205e)
#         ;
#
#
#
#
#             var marker_947283a3ec1e8c4b643cb72b243bebcc = L.marker(
#                 [42.21480000000003, -71.033],
#                 {}
#             ).addTo(map_d3ccab4d49b5201c804b8879c7984fe8);
#
#
#         var popup_24970a27a0952377347b7b5aeac6a922 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d546d675dedfe2c93052a65a7f6f515f = $(`&lt;div id=&quot;html_d546d675dedfe2c93052a65a7f6f515f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.21480000000003, -71.033]&lt;/div&gt;`)[0];
#                 popup_24970a27a0952377347b7b5aeac6a922.setContent(html_d546d675dedfe2c93052a65a7f6f515f);
#
#
#
#         marker_947283a3ec1e8c4b643cb72b243bebcc.bindPopup(popup_24970a27a0952377347b7b5aeac6a922)
#         ;
#
#
#
#
#             var marker_3914cd99a62c83d92db06859c32257af = L.marker(
#                 [42.3505, -71.10540000000002],
#                 {}
#             ).addTo(map_d3ccab4d49b5201c804b8879c7984fe8);
#
#
#         var popup_70b7eaab2654a99b99f09bb389f64093 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06ede31eeb8bd504df5af3e9107f4a28 = $(`&lt;div id=&quot;html_06ede31eeb8bd504df5af3e9107f4a28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.3505, -71.10540000000002]&lt;/div&gt;`)[0];
#                 popup_70b7eaab2654a99b99f09bb389f64093.setContent(html_06ede31eeb8bd504df5af3e9107f4a28);
#
#
#
#         marker_3914cd99a62c83d92db06859c32257af.bindPopup(popup_70b7eaab2654a99b99f09bb389f64093)
#         ;
#
#
#
#
#             var marker_54adb

# %%
sns.factorplot(data = x_10, x = 'label',kind = 'count')
# Out:
# C:\Users\16695\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
x_7 = x.copy()
km_7 = KMeans(n_clusters=7)
clusters = km_7.fit_predict(x_7)
x_7["label"] = clusters
centroids = km_7.cluster_centers_
y = np.delete(centroids,[2],axis=1)
import folium
centroid = y.tolist()
# Plotting the centroids on google map using Folium library.
map = folium.Map(location=[42.3372844, -71.0657244], zoom_start = 25)
for point in range(0, len(centroid)):
    folium.Marker(centroid[point], popup = centroid[point]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1752f5cffc6ccd5c59cb101f8abfe4a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1752f5cffc6ccd5c59cb101f8abfe4a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1752f5cffc6ccd5c59cb101f8abfe4a0 = L.map(
#                 &quot;map_1752f5cffc6ccd5c59cb101f8abfe4a0&quot;,
#                 {
#                     center: [42.3372844, -71.0657244],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d576b9d1c4d0791775c1b86d3aa5118 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1752f5cffc6ccd5c59cb101f8abfe4a0);
#
#
#             var marker_d12749d10790efe3cfb866ebe31bb993 = L.marker(
#                 [42.3429, -71.1003],
#                 {}
#             ).addTo(map_1752f5cffc6ccd5c59cb101f8abfe4a0);
#
#
#         var popup_a430e8e2b7af0ccc80ef33f87794080d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_caa024606d7be2b7680b7f819e3a0559 = $(`&lt;div id=&quot;html_caa024606d7be2b7680b7f819e3a0559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.3429, -71.1003]&lt;/div&gt;`)[0];
#                 popup_a430e8e2b7af0ccc80ef33f87794080d.setContent(html_caa024606d7be2b7680b7f819e3a0559);
#
#
#
#         marker_d12749d10790efe3cfb866ebe31bb993.bindPopup(popup_a430e8e2b7af0ccc80ef33f87794080d)
#         ;
#
#
#
#
#             var marker_9cbc556b6ff4dd34d084e68098648403 = L.marker(
#                 [42.36557547855409, -71.06402562608102],
#                 {}
#             ).addTo(map_1752f5cffc6ccd5c59cb101f8abfe4a0);
#
#
#         var popup_381c8afb93194f645965ca09e74da416 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1b4b2f2b78fbe5416ffd4ef9455bff2 = $(`&lt;div id=&quot;html_c1b4b2f2b78fbe5416ffd4ef9455bff2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.36557547855409, -71.06402562608102]&lt;/div&gt;`)[0];
#                 popup_381c8afb93194f645965ca09e74da416.setContent(html_c1b4b2f2b78fbe5416ffd4ef9455bff2);
#
#
#
#         marker_9cbc556b6ff4dd34d084e68098648403.bindPopup(popup_381c8afb93194f645965ca09e74da416)
#         ;
#
#
#
#
#             var marker_07573f43be6c0721fdafd063f78293ef = L.marker(
#                 [42.246234392276904, -71.04713290276769],
#                 {}
#             ).addTo(map_1752f5cffc6ccd5c59cb101f8abfe4a0);
#
#
#         var popup_f5c8172e1b77205e87337fd2dc109b97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_820c19ed4a32e10ea37e757de00e6831 = $(`&lt;div id=&quot;html_820c19ed4a32e10ea37e757de00e6831&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.246234392276904, -71.04713290276769]&lt;/div&gt;`)[0];
#                 popup_f5c8172e1b77205e87337fd2dc109b97.setContent(html_820c19ed4a32e10ea37e757de00e6831);
#
#
#
#         marker_07573f43be6c0721fdafd063f78293ef.bindPopup(popup_f5c8172e1b77205e87337fd2dc109b97)
#         ;
#
#
#
#
#             var marker_5713caa36576e388258ddd8ff29734a5 = L.marker(
#                 [42.3647, -71.0542],
#                 {}
#             ).addTo(map_1752f5cffc6ccd5c59cb101f8abfe4a0);
#
#
#         var popup_8e39011224db10a92a29274642402a6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b7b490cdd5d6e1d52898f5255444d56e = $(`&lt;div id=&quot;html_b7b490cdd5d6e1d52898f5255444d56e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.3647, -71.0542]&lt;/div&gt;`)[0];
#                 popup_8e39011224db10a92a29274642402a6b.setContent(html_b7b490cdd5d6e1d52898f5255444d56e);
#
#
#
#         marker_5713caa36576e388258ddd8ff29734a5.bindPopup(popup_8e39011224db10a92a29274642402a6b)
#         ;
#
#
#
#
#             var marker_b4dea60449eb4ff00ad8169bda217a5b = L.marker(
#                 [42.35039439053213, -71.09251564492061],
#                 {}
#             ).addTo(map_1752f5cffc6ccd5c59cb101f8abfe4a0);
#
#
#         var popup_18cd9cbf919c6a7482834493d2749732 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a2d128481cbd3445e8921073532a5220 = $(`&lt;div id=&quot;html_a2d128481cbd3445e8921073532a5220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[42.35039439053213, -71.09251564492061]&lt;/div&gt;`)[0];
#                 popup_18cd9cbf919c6a7482834493d2749732.setContent(html_a2d128481cbd3445e8921073532a5220);
#
#
#
#         marker_b4dea60449eb4ff00ad8169bda217a5b.bindPopup(popup_18cd9cbf919c6a7482834493d2749732)
#         ;

# %%
sns.factorplot(data = x_7, x = 'label',kind = 'count')
# Out:
# C:\Users\16695\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
